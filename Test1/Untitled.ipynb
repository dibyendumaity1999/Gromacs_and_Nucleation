# %%
fo = open("traj_nacl.gro")

# %%
r = fo.read()

# %%
l = fo.readlines()

# %%
l
# Out:
# ['Generated by trjconv : NACL in water t=   0.00000\n',
#  ' 6183\n',
#  '    1CL      CL    1   1.896   1.986   2.148\n',
#  '    1NA      NA    2   2.035   2.219   2.078\n',
#  ' 2011NA      NA 6030   1.229   0.786   0.902\n',
#  ' 2012NA      NA 6031   2.848   1.146   1.778\n',
#  ' 2013NA      NA 6032   0.033   0.887   2.599\n',
#  ' 2014NA      NA 6033   1.178   0.369   0.470\n',
#  ' 2015NA      NA 6034   3.335   1.565   1.286\n',
#  ' 2016NA      NA 6035   2.824   2.608   2.115\n',
#  ' 2017NA      NA 6036   0.194   1.668   3.075\n',
#  ' 2018NA      NA 6037   0.656   1.340   2.388\n',
#  ' 2019NA      NA 6038   1.041   2.147   1.828\n',
#  ' 2020NA      NA 6039   0.315   0.144   2.610\n',
#  ' 2021NA      NA 6040   3.566   1.576   3.156\n',
#  ' 2022NA      NA 6041   0.536   3.651   2.651\n',
#  ' 2023NA      NA 6042   2.190   0.151   2.532\n',
#  ' 2024NA      NA 6043   3.011   0.439   0.567\n',
#  ' 2025NA      NA 6044   1.261   3.091   1.936\n',
# ...

# %%
print("no. of lines are 156")
# Out:
# no. of lines are 156

# %%
for i in range(len(l)):
    if len(l[i].split()) == 6:
        myLine = l[i].split()
        myLine[0] = str((i%159) - 1)+myLine[1]
        myLine[2] = str((i%159) - 1)
        l[i] = l2s(myLine)

# %%
for i in range(len(l)):
    if len(l[i].split()) ==1 :
        l[i] = ' 156\n'

# %%
def l2s(l):
    s = " "+ l[0] + "      " + l[1]+" "+l[2]+"   "+l[3]+"   "+l[4]+"   "+l[5]+"\n"
    return s

# %%
l[4].split()
# Out:
# ['2011NA', 'NA', '6030', '1.229', '0.786', '0.902']

# %%
s.split()
# Out:
# ['2011NA', 'NA', '6030', '1.229', '0.786', '0.902']

# %%
s
# Out:
# ' 2011NA      NA 6030   1.229   0.786   0.902\n'

# %%
wf = open('clean_nacl.gro','a')

# %%
dir(wf)
# Out:
# ['_CHUNK_SIZE',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
for item in l:
    wf.write(item)
wf.close()

# %%
open('clean_nacl.gro').read()
# Out:
# 'Generated by trjconv : NACL in water t=   0.00000\n 156\n 1CL      CL 1   1.896   1.986   2.148\n 2NA      NA 2   2.035   2.219   2.078\n 3NA      NA 3   1.229   0.786   0.902\n 4NA      NA 4   2.848   1.146   1.778\n 5NA      NA 5   0.033   0.887   2.599\n 6NA      NA 6   1.178   0.369   0.470\n 7NA      NA 7   3.335   1.565   1.286\n 8NA      NA 8   2.824   2.608   2.115\n 9NA      NA 9   0.194   1.668   3.075\n 10NA      NA 10   0.656   1.340   2.388\n 11NA      NA 11   1.041   2.147   1.828\n 12NA      NA 12   0.315   0.144   2.610\n 13NA      NA 13   3.566   1.576   3.156\n 14NA      NA 14   0.536   3.651   2.651\n 15NA      NA 15   2.190   0.151   2.532\n 16NA      NA 16   3.011   0.439   0.567\n 17NA      NA 17   1.261   3.091   1.936\n 18NA      NA 18   3.859   3.598   3.902\n 19NA      NA 19   3.598   3.653   3.634\n 20NA      NA 20   0.466   0.157   0.001\n 21NA      NA 21   3.379   3.384   1.440\n 22NA      NA 22   3.204   0.915   3.327\n 23NA      NA 23   3.486   3.483  
# ...
